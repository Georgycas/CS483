# %% [markdown]
# # Module1-Ex3 - Getting and Knowing your Data

# %% [markdown]
# - Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries and read the dataset `chipo.csv`

# %%
import pandas as pd

# %%
df = pd.read_csv('chipo.csv')

# %% [markdown]
# ### Step 2. See the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 3. What is the number of observations in the dataset?

# %%
# Solution 2
print(f"There are {df.shape[0]} observation in the dataset")
# Out:
# There are 4622 observation in the dataset

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ### Step 4. What is the number of columns in the dataset?

# %%
print(f"there are {df.shape[1]} number of colums")
# Out:
# there are 5 number of colums

# %% [markdown]
# ### Step 5. Print the name of all the columns.

# %%
list(df.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 6. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df[:10] #first ten observation
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.loc[2] #this uses the index value 2
# Out:
# order_id                             1
# quantity                             1
# item_name             Nantucket Nectar
# choice_description             [Apple]
# item_price                      $3.39
# Name: 2, dtype: object

# %%
df2 = df # this points to the same location
df2 = df.copy() #this is a shallow copy

# %%
df2.drop(2, axis = 0, inplace= True) #2 searches axis = 0 means a row axis = 1 means a column

# %%
df2[:10]
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 0                                                 NaN     $2.39
# 1                                        [Clementine]     $3.39
# 3                                                 NaN     $2.39
# ...

# %%
df2.loc[3] # index of the row
df2.iloc[2] # order of the row
# Out:
# order_id                                                  1
# quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 3, dtype: object

# %%
df2.set_index('order_id', inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11268\3533013880.py in ?()
# ----> 1 df2.set_index('order_id', inplace= True)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['order_id'] are in the columns"

# %%
df2.reset_index()
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1  Chips and Tomatillo-Green Chili Salsa
# 3            2         2                           Chicken Bowl
# 4            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4616      1833         1                          Steak Burrito
# 4617      1833         1                          Steak Burrito
# 4618      1834         1                     Chicken Salad Bowl
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 7. Which was the most-ordered item?

# %%
df[:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.groupby('item_name').sum()
# Out:
#                                        order_id  quantity  \
# item_name
# 6 Pack Soft Drink                         52322        55
# Barbacoa Bowl                             53972        66
# Barbacoa Burrito                          74718        91
# Barbacoa Crispy Tacos                      5613        12
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Soft Tacos                       18725        25
# Bottled Water                            175944       211
# Bowl                                        472         4
# Burrito                                    1550         6
# Canned Soda                               76396       126
# Canned Soft Drink                        304753       351
# Carnitas Bowl                             62742        71
# Carnitas Burrito                          51652        60
# Carnitas Crispy Tacos                      5868         8
# Carnitas Salad                             1500         1
# ...

# %%
df[['item_name','quantity']].groupby('item_name').sum()
# Out:
#                                        quantity
# item_name
# 6 Pack Soft Drink                            55
# Barbacoa Bowl                                66
# Barbacoa Burrito                             91
# Barbacoa Crispy Tacos                        12
# Barbacoa Salad Bowl                          10
# Barbacoa Soft Tacos                          25
# Bottled Water                               211
# Bowl                                          4
# Burrito                                       6
# Canned Soda                                 126
# Canned Soft Drink                           351
# Carnitas Bowl                                71
# Carnitas Burrito                             60
# Carnitas Crispy Tacos                         8
# Carnitas Salad                                1
# Carnitas Salad Bowl                           6
# Carnitas Soft Tacos                          40
# Chicken Bowl                                761
# ...

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False)
# Out:
#                                        quantity
# item_name
# Chicken Bowl                                761
# Chicken Burrito                             591
# Chips and Guacamole                         506
# Steak Burrito                               386
# Canned Soft Drink                           351
# Chips                                       230
# Steak Bowl                                  221
# Bottled Water                               211
# Chips and Fresh Tomato Salsa                130
# Canned Soda                                 126
# Chicken Salad Bowl                          123
# Chicken Soft Tacos                          120
# Side of Chips                               110
# Veggie Burrito                               97
# Barbacoa Burrito                             91
# Veggie Bowl                                  87
# Carnitas Bowl                                71
# Barbacoa Bowl                                66
# ...

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False).head(1)
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False)[:1]
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False).iloc[0]
# Out:
# quantity    761
# Name: Chicken Bowl, dtype: int64

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False).index[0]
# Out:
# 'Chicken Bowl'

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False).iloc[0].quantity
# Out:
# np.int64(761)

# %%
df[['item_name','quantity']].groupby('item_name').sum().sort_values(by='quantity', ascending= False).values[0][0]
# Out:
# np.int64(761)

# %% [markdown]
# ### Step 8. For the most-ordered item, how many items were ordered?

# %% [markdown]
# ### Step 9. What was the most ordered item in the choice_description column?

# %% [markdown]
# ### Step 10. How many items were orderd in total?

# %%
#total number of orders or different items
#assuming order_id is sorted
df.sort_values(by="order_id", ascending= False).iloc[0,0]
# Out:
# np.int64(1834)

# %%
df['item_name'].unique()
len(df['item_name'].unique())
# Out:
# 50

# %% [markdown]
# ### Step 11. Turn the item price into a float

# %% [markdown]
# #### Step 11.a. Check the item price type

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df['item_price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 11.b. Create a lambda function and change the type of item price

# %%
df['item_price'][:10]
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# 5    $10.98
# 6     $1.69
# 7    $11.75
# 8     $9.25
# 9     $9.25
# Name: item_price, dtype: object

# %%
elim_dollar = lambda x:float(x[1:])

df['item_price'] = df['item_price'].apply(elim_dollar)

# %%
inv_dollar = lambda x: '$' +str(x)
df['item_price'] = df['item_price'].apply(inv_dollar)

# %% [markdown]
# #### Step 11.c. Check the item price type

# %% [markdown]
# ### Step 12. How much was the revenue for the period in the dataset?

# %%
df[:3]
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39

# %%
(df['quantity'] * df['item_price']).sum()
# Out:
# np.float64(39237.02)

# %% [markdown]
# ### Step 13. How many orders were made in the period?

# %% [markdown]
# ### Step 14. What is the average revenue amount per order?

# %%
# Solution 1

# %% [markdown]
# ### Step 15. How many different items are sold?
